# %% [markdown]
# ## This script just runs defineLocations, calcDistances, and generateFlows all at once
# This only exists because the size and values of these values depend on each other, so it's important to make sure they're all synced up on the same underlying variables
# - If you need to change key parameters (e.g. how many locations are generated), you must go into the associated script to do it. I know this is not ideal lol, it'd be better to define as a function, but I beg your forgiveness

# %%
# %run ./defineLocations.ipynb
# %run ./calcDistances.ipynb
# %run ./generateFlows.ipynb
# Out:
# Number of locations: 10
# Number of locations: 10
